# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
# Set random seed for reproducibility
tf.random.set_seed(42)

# %%
# Load the input and target data
X = pd.read_excel('data1319.xlsx', sheet_name=0, usecols='D:S', skiprows=1, nrows=765).values
y = pd.read_excel('data1319.xlsx', sheet_name=0, usecols='T', skiprows=1, nrows=765).values

# %%
# Expand dimensions of target data if necessary
t = np.expand_dims(y, axis=1) if y.ndim == 1 else y

# %%
# Normalize input and target data
input_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()

# %%
x_scaled = input_scaler.fit_transform(X)
t_scaled = target_scaler.fit_transform(t)

# %%
# Split data into training, validation, and testing sets
x_train, x_temp, t_train, t_temp = train_test_split(x_scaled, t_scaled, test_size=0.3, random_state=42)
x_val, x_test, t_val, t_test = train_test_split(x_temp, t_temp, test_size=0.5, random_state=42)

# %%
# Create a fitting network
hidden_layer_size = 10
model = Sequential([
    Dense(hidden_layer_size, activation='relu', input_shape=(x_scaled.shape[1],)),
    Dense(t_scaled.shape[1], activation='relu')
])
# Out:
# /Users/charlesyamamura/ls/envs/aienv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Display the model summary
print("Model Summary:")
model.summary()
# Out:
# Model Summary:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 10)             │           170 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 181 (724.00 B)
#  Trainable params: 181 (724.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
model.compile(optimizer=Adam(), loss=MeanSquaredError(), metrics=['mae'])

# %%
# Train the network
history = model.fit(x_train, t_train, epochs=100, batch_size=10,
                    validation_data=(x_val, t_val), verbose=1)
# Out:
# Epoch 1/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.6704 - mae: 0.6796 - val_loss: 0.2241 - val_mae: 0.3760
# Epoch 2/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1280 - mae: 0.2897 - val_loss: 0.1350 - val_mae: 0.3027
# Epoch 3/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1075 - mae: 0.2562 - val_loss: 0.1270 - val_mae: 0.2934
# Epoch 4/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1002 - mae: 0.2457 - val_loss: 0.1180 - val_mae: 0.2797
# Epoch 5/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0927 - mae: 0.2347 - val_loss: 0.1091 - val_mae: 0.2675
# Epoch 6/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0856 - mae: 0.2239 - val_loss: 0.1006 - val_mae: 0.2561
# Epoch 7/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0788 - mae: 0.2138 - val_loss: 0.0925 - val_mae: 0.2448
# Epoch 8/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0726 - mae: 0.2045 - val_loss: 0.0851 - val_mae: 0.2337
# Epoch 9/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0670 - mae: 0.1956 - val_loss: 0.0785 - val_mae: 0.2235
# Epoch 10/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0621 - mae: 0.1870 - val_loss: 0.0727 - val_mae: 0.2137
# Epoch 11/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0578 - mae: 0.1792 - val_loss: 0.0679 - val_mae: 0.2050
# Epoch 12/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0543 - mae: 0.1718 - val_loss: 0.0639 - val_mae: 0.1970
# Epoch 13/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0514 - mae: 0.1655 - val_loss: 0.0606 - val_mae: 0.1902
# Epoch 14/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0489 - mae: 0.1603 - val_loss: 0.0579 - val_mae: 0.1842
# Epoch 15/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0470 - mae: 0.1558 - val_loss: 0.0557 - val_mae: 0.1789
# Epoch 16/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0454 - mae: 0.1525 - val_loss: 0.0540 - val_mae: 0.1745
# Epoch 17/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0439 - mae: 0.1497 - val_loss: 0.0524 - val_mae: 0.1705
# Epoch 18/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0427 - mae: 0.1473 - val_loss: 0.0512 - val_mae: 0.1669
# Epoch 19/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0418 - mae: 0.1453 - val_loss: 0.0501 - val_mae: 0.1640
# Epoch 20/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0410 - mae: 0.1435 - val_loss: 0.0492 - val_mae: 0.1616
# Epoch 21/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0402 - mae: 0.1418 - val_loss: 0.0484 - val_mae: 0.1588
# Epoch 22/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0396 - mae: 0.1404 - val_loss: 0.0476 - val_mae: 0.1565
# Epoch 23/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0391 - mae: 0.1391 - val_loss: 0.0470 - val_mae: 0.1543
# Epoch 24/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0386 - mae: 0.1378 - val_loss: 0.0464 - val_mae: 0.1521
# Epoch 25/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0382 - mae: 0.1367 - val_loss: 0.0459 - val_mae: 0.1501
# Epoch 26/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0379 - mae: 0.1356 - val_loss: 0.0455 - val_mae: 0.1482
# Epoch 27/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0376 - mae: 0.1348 - val_loss: 0.0456 - val_mae: 0.1518
# Epoch 28/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0362 - mae: 0.1346 - val_loss: 0.0436 - val_mae: 0.1470
# Epoch 29/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0337 - mae: 0.1295 - val_loss: 0.0416 - val_mae: 0.1401
# Epoch 30/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0320 - mae: 0.1259 - val_loss: 0.0402 - val_mae: 0.1353
# Epoch 31/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0308 - mae: 0.1228 - val_loss: 0.0391 - val_mae: 0.1314
# Epoch 32/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0298 - mae: 0.1198 - val_loss: 0.0383 - val_mae: 0.1287
# Epoch 33/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0290 - mae: 0.1170 - val_loss: 0.0376 - val_mae: 0.1262
# Epoch 34/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0283 - mae: 0.1145 - val_loss: 0.0370 - val_mae: 0.1238
# Epoch 35/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0279 - mae: 0.1125 - val_loss: 0.0366 - val_mae: 0.1223
# Epoch 36/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0275 - mae: 0.1108 - val_loss: 0.0364 - val_mae: 0.1212
# Epoch 37/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0272 - mae: 0.1097 - val_loss: 0.0364 - val_mae: 0.1212
# Epoch 38/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0270 - mae: 0.1089 - val_loss: 0.0363 - val_mae: 0.1208
# Epoch 39/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0269 - mae: 0.1082 - val_loss: 0.0362 - val_mae: 0.1203
# Epoch 40/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0267 - mae: 0.1075 - val_loss: 0.0362 - val_mae: 0.1200
# Epoch 41/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0266 - mae: 0.1069 - val_loss: 0.0362 - val_mae: 0.1196
# Epoch 42/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0265 - mae: 0.1066 - val_loss: 0.0361 - val_mae: 0.1194
# Epoch 43/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0264 - mae: 0.1061 - val_loss: 0.0361 - val_mae: 0.1194
# Epoch 44/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0264 - mae: 0.1058 - val_loss: 0.0360 - val_mae: 0.1193
# Epoch 45/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0263 - mae: 0.1054 - val_loss: 0.0360 - val_mae: 0.1193
# Epoch 46/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0262 - mae: 0.1052 - val_loss: 0.0360 - val_mae: 0.1194
# Epoch 47/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0262 - mae: 0.1049 - val_loss: 0.0360 - val_mae: 0.1195
# Epoch 48/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0261 - mae: 0.1047 - val_loss: 0.0360 - val_mae: 0.1196
# Epoch 49/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0261 - mae: 0.1045 - val_loss: 0.0360 - val_mae: 0.1197
# Epoch 50/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0261 - mae: 0.1046 - val_loss: 0.0356 - val_mae: 0.1183
# Epoch 51/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0258 - mae: 0.1044 - val_loss: 0.0344 - val_mae: 0.1168
# Epoch 52/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0251 - mae: 0.1039 - val_loss: 0.0334 - val_mae: 0.1158
# Epoch 53/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0246 - mae: 0.1034 - val_loss: 0.0329 - val_mae: 0.1158
# Epoch 54/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0243 - mae: 0.1031 - val_loss: 0.0324 - val_mae: 0.1152
# Epoch 55/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0240 - mae: 0.1027 - val_loss: 0.0323 - val_mae: 0.1159
# Epoch 56/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0238 - mae: 0.1025 - val_loss: 0.0323 - val_mae: 0.1172
# Epoch 57/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0236 - mae: 0.1022 - val_loss: 0.0322 - val_mae: 0.1168
# Epoch 58/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0234 - mae: 0.1014 - val_loss: 0.0322 - val_mae: 0.1171
# Epoch 59/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0233 - mae: 0.1011 - val_loss: 0.0321 - val_mae: 0.1168
# Epoch 60/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0232 - mae: 0.1007 - val_loss: 0.0321 - val_mae: 0.1167
# Epoch 61/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0231 - mae: 0.1002 - val_loss: 0.0319 - val_mae: 0.1161
# Epoch 62/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0230 - mae: 0.1001 - val_loss: 0.0317 - val_mae: 0.1152
# Epoch 63/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0230 - mae: 0.1007 - val_loss: 0.0293 - val_mae: 0.1089
# Epoch 64/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0204 - mae: 0.0985 - val_loss: 0.0226 - val_mae: 0.1008
# Epoch 65/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0177 - mae: 0.0964 - val_loss: 0.0201 - val_mae: 0.0993
# Epoch 66/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0159 - mae: 0.0937 - val_loss: 0.0187 - val_mae: 0.0991
# Epoch 67/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0150 - mae: 0.0922 - val_loss: 0.0164 - val_mae: 0.0921
# Epoch 68/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0142 - mae: 0.0895 - val_loss: 0.0168 - val_mae: 0.0946
# Epoch 69/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0138 - mae: 0.0895 - val_loss: 0.0160 - val_mae: 0.0924
# Epoch 70/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0134 - mae: 0.0884 - val_loss: 0.0156 - val_mae: 0.0913
# Epoch 71/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0130 - mae: 0.0870 - val_loss: 0.0157 - val_mae: 0.0927
# Epoch 72/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0129 - mae: 0.0873 - val_loss: 0.0147 - val_mae: 0.0887
# Epoch 73/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0126 - mae: 0.0859 - val_loss: 0.0145 - val_mae: 0.0883
# Epoch 74/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0123 - mae: 0.0850 - val_loss: 0.0146 - val_mae: 0.0890
# Epoch 75/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0123 - mae: 0.0852 - val_loss: 0.0144 - val_mae: 0.0886
# Epoch 76/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0122 - mae: 0.0849 - val_loss: 0.0144 - val_mae: 0.0883
# Epoch 77/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0121 - mae: 0.0845 - val_loss: 0.0139 - val_mae: 0.0861
# Epoch 78/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0120 - mae: 0.0841 - val_loss: 0.0137 - val_mae: 0.0852
# Epoch 79/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0118 - mae: 0.0834 - val_loss: 0.0138 - val_mae: 0.0860
# Epoch 80/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0117 - mae: 0.0830 - val_loss: 0.0134 - val_mae: 0.0840
# Epoch 81/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0115 - mae: 0.0819 - val_loss: 0.0138 - val_mae: 0.0855
# Epoch 82/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0116 - mae: 0.0827 - val_loss: 0.0134 - val_mae: 0.0844
# Epoch 83/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0115 - mae: 0.0821 - val_loss: 0.0136 - val_mae: 0.0851
# Epoch 84/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0115 - mae: 0.0822 - val_loss: 0.0136 - val_mae: 0.0849
# Epoch 85/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0115 - mae: 0.0819 - val_loss: 0.0131 - val_mae: 0.0826
# Epoch 86/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0114 - mae: 0.0814 - val_loss: 0.0133 - val_mae: 0.0834
# Epoch 87/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0112 - mae: 0.0807 - val_loss: 0.0135 - val_mae: 0.0849
# Epoch 88/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0113 - mae: 0.0812 - val_loss: 0.0132 - val_mae: 0.0833
# Epoch 89/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0112 - mae: 0.0807 - val_loss: 0.0133 - val_mae: 0.0840
# Epoch 90/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0112 - mae: 0.0807 - val_loss: 0.0130 - val_mae: 0.0822
# Epoch 91/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0112 - mae: 0.0806 - val_loss: 0.0132 - val_mae: 0.0831
# Epoch 92/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0112 - mae: 0.0803 - val_loss: 0.0130 - val_mae: 0.0822
# Epoch 93/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0111 - mae: 0.0797 - val_loss: 0.0132 - val_mae: 0.0831
# Epoch 94/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0111 - mae: 0.0798 - val_loss: 0.0131 - val_mae: 0.0828
# Epoch 95/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0110 - mae: 0.0796 - val_loss: 0.0132 - val_mae: 0.0833
# Epoch 96/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0110 - mae: 0.0796 - val_loss: 0.0132 - val_mae: 0.0833
# Epoch 97/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0109 - mae: 0.0791 - val_loss: 0.0133 - val_mae: 0.0837
# Epoch 98/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0110 - mae: 0.0794 - val_loss: 0.0130 - val_mae: 0.0824
# Epoch 99/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0110 - mae: 0.0794 - val_loss: 0.0129 - val_mae: 0.0818
# Epoch 100/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0109 - mae: 0.0789 - val_loss: 0.0130 - val_mae: 0.0821

# %%
# Test the network
y_pred = model.predict(x_test)
performance = model.evaluate(x_test, t_test, verbose=0)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
# Save the trained model
model_save_path = "mktRegMdl.keras"
model.save(model_save_path)
print(f"Model saved at: {model_save_path}")
# Out:
# Model saved at: mktRegMdl.keras

# %%
# Calculate training and testing adjusted accuracies
train_mse = model.evaluate(x_train, t_train, verbose=0)[0]
test_mse = performance[0]
target_variance = np.var(t_scaled)

# %%
train_accuracy = max(0, 1 - (train_mse / target_variance))
test_accuracy = max(0, 1 - (test_mse / target_variance))

# %%
# Calculate R-squared for training and testing
train_pred = model.predict(x_train)
test_pred = model.predict(x_test)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
train_r2 = r2_score(t_train, train_pred)
test_r2 = r2_score(t_test, test_pred)

# %%
# Print performance results
print("\nPerformance Results:")
print("Test Performance (MSE):", test_mse)
print("Adjusted Training Accuracy:", train_accuracy)
print("Adjusted Testing Accuracy:", test_accuracy)
print("Training R-squared:", train_r2)
print("Testing R-squared:", test_r2)
# Out:
# Performance Results:
# Test Performance (MSE): 0.012860553339123726
# Adjusted Training Accuracy: 0.7944397808416177
# Adjusted Testing Accuracy: 0.7492411466981841
# Training R-squared: 0.7900474966825193
# Testing R-squared: 0.7724169697232793

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(t_test, y_pred)
mae
# Out:
# 0.08075864404729736

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(t_test, y_pred)
mse
# Out:
# 0.012860554703092551

# %%
# Plot training and validation loss
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Plot adjusted accuracy results
epochs = range(1, len(history.history['loss']) + 1)
train_accuracy_epoch = [max(0, 1 - (loss / target_variance)) for loss in history.history['loss']]
val_accuracy_epoch = [max(0, 1 - (loss / target_variance)) for loss in history.history['val_loss']]
plt.figure(figsize=(8, 6))
plt.plot(epochs, train_accuracy_epoch, label='Training Adjusted Accuracy')
plt.plot(epochs, val_accuracy_epoch, label='Validation Adjusted Accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Adjusted Accuracy')
plt.title('Training and Validation Adjusted Accuracy')
plt.show()

# %%
# Optional: Generate a simple function for deployment
def my_neural_network_function(new_x):
    new_x_scaled = input_scaler.transform(new_x)
    y_scaled = model.predict(new_x_scaled)
    return target_scaler.inverse_transform(y_scaled)
